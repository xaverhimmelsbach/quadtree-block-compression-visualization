# %%
import run_utils
from plain_run import plain_run

# %%
# test_black_white

input_path = './data/input/test_black_white.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_detail_high.png

input_path = './data/input/test_detail_high.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_fine_print.png

input_path = './data/input/test_fine_print.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'CatmullRom'
upsampling_interpolator = 'CatmullRom'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_large.png

input_path = './data/input/test_large.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = False
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_pixel.png

input_path = './data/input/test_pixel.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_tiny.png

input_path = './data/input/test_tiny.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_color.png

input_path = './data/input/test_color.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_detail_low.png

input_path = './data/input/test_detail_low.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_gradient.png

input_path = './data/input/test_gradient.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_medium.png

input_path = './data/input/test_medium.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = False
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)

# %%
# test_small.png

input_path = './data/input/test_small.png'
name = 'optimal'
similarity_cutoff = '0.7'
downsampling_interpolator = 'NearestNeighbor'
upsampling_interpolator = 'NearestNeighbor'
archive_format = 'gzip'
encoding_parallelism = True
skip_oob_blocks = True
deduplicate_blocks_enable = True
deduplicate_blocks_minimal_similarity = '0.7'
decoding_parallelism = True

run_utils.run_visualization_and_timings(input_path, 'optimal', similarity_cutoff, downsampling_interpolator,
                                        upsampling_interpolator, archive_format, encoding_parallelism, skip_oob_blocks,
                                        deduplicate_blocks_enable, deduplicate_blocks_minimal_similarity, decoding_parallelism)
