# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the default theme
sns.set_theme()
sns.set_style('whitegrid')
sns.set_context('paper')

# %%
# Load data
df = pd.read_csv('../data/optimal.csv')
df_plain_run = pd.read_csv('../data/plain_run.csv')
df_jpeg = pd.read_csv('../data/jpeg.csv')

# _x = optimal, _y = jpeg, rest = plain run
df_merged = pd.merge(pd.merge(df, df_jpeg, on='file_name'), df_plain_run, on='file_name')

df_merged['time_ratio'] = df_merged['transcoding_time_x'] / df_merged['transcoding_time']

df_merged
# Out:
#            file_name  file_size_original_x  file_size_transcoded_x  \
# 0          test_tiny                245004                   95088
# 1         test_small                974331                  382346
# 2        test_medium               3886238                 1480937
# 3         test_large              14784572                 5855154
# 4    test_detail_low                345237                  235104
# 5   test_detail_high                785610                  322222
# 6         test_pixel                  7649                     904
# 7      test_gradient                142670                     907
# 8   test_black_white                331351                  174028
# 9         test_color                502888                  187237
# 10   test_fine_print                 30956                  130745
#
#     compression_ratio_x  transcoding_time_x  file_size_original_y  \
# 0              0.388108                 736                245004
# 1              0.392419                8818                974331
# 2              0.381072                1392               3886238
# 3              0.396031               11300              14784572
# 4              0.680993                4922                345237
# 5              0.410155                6409                785610
# 6              0.118185                  37                  7649
# 7              0.006357                  48                142670
# 8              0.525207                3737                331351
# 9              0.372323                3653                502888
# 10             4.223575                1883                 30956
#
#     file_size_transcoded_y  compression_ratio_y  transcoding_time_y  \
# 0                    39110             0.159630                  33
# 1                   155999             0.160109                  59
# 2                   642346             0.165287                 187
# 3                  2559562             0.173124                 743
# 4                    85805             0.248539                  47
# 5                   131051             0.166814                  57
# 6                     3804             0.497320                  22
# 7                    18179             0.127420                  32
# 8                    54502             0.164484                  40
# 9                    61321             0.121938                  52
# 10                   67485             2.180030                  31
#
#     file_size_original  file_size_transcoded  compression_ratio  \
# 0               245004               1207041           4.926618
# 1               974331               4533948           4.653396
# 2              3886238              14702810           3.783301
# 3             14784572              52259864           3.534757
# 4               345237               3526027          10.213352
# 5               785610               3602062           4.585051
# 6                 7649                 68090           8.901817
# 7               142670                 36116           0.253144
# 8               331351               2748058           8.293495
# 9               502888               2811228           5.590167
# 10               30956                   659           0.021288
#
#     transcoding_time  time_ratio
# 0                309    2.381877
# 1               1411    6.249468
# 2               3916    0.355465
# 3              19635    0.575503
# 4               1126    4.371226
# 5               1169    5.482464
# 6                 94    0.393617
# 7                 85    0.564706
# 8                969    3.856553
# 9               1033    3.536302
# 10               235    8.012766

# %%
# Compression ratio
df_sorted = df_merged.sort_values('compression_ratio_x')

df_first = df_sorted.loc[:, ('file_name', 'compression_ratio')].rename(
    columns={'compression_ratio': 'c'})
df_first['class'] = 'plain_run'

df_second = df_sorted.loc[:, ('file_name', 'compression_ratio_y')].rename(
    columns={'compression_ratio_y': 'c'})
df_second['class'] = 'jpeg'

df_third = df_sorted.loc[:, ('file_name', 'compression_ratio_x')].rename(
    columns={'compression_ratio_x': 'c'})
df_third['class'] = 'optimal'

# Concatenate data frames
df_concat = pd.concat([df_first, df_second, df_third])

# Create a visualization
g = sns.relplot(
    x='file_name',
    y='c',
    data=df_concat,
    hue='class',
    aspect=16/9,
    facet_kws={'legend_out': False},
)

# Bold 10⁰
yticklabels = g.ax.get_yticklabels()
yticklabels[4].set_fontweight('bold')
g.set_yticklabels(yticklabels)

# Draw line through 10⁰
g.ax.axhline(y=10**0, color='k', linestyle='--', linewidth=1)

g.set(xlabel='File name', ylabel='Compression ratio', yscale='log')

legend = g.axes.flat[0].get_legend()
legend.set_title('Codec')
for t, l in zip(legend.texts, ['Plain quadtree ', 'JPEG', 'Optimal']):
    t.set_text(l)

plt.xticks(rotation=45)

plt.show()

# %%
# Transcoding time
df_sorted = df_merged.sort_values('transcoding_time_x')

df_first = df_sorted.loc[:, ('file_name', 'transcoding_time')].rename(
    columns={'transcoding_time': 't'})
df_first['class'] = 'plain_run'

df_second = df_sorted.loc[:, ('file_name', 'transcoding_time_y')].rename(
    columns={'transcoding_time_y': 't'})
df_second['class'] = 'jpeg'

df_third = df_sorted.loc[:, ('file_name', 'transcoding_time_x')].rename(
    columns={'transcoding_time_x': 't'})
df_third['class'] = 'optimal'

# Concatenate data frames
df_concat = pd.concat([df_first, df_second, df_third])

# Create a visualization
g = sns.relplot(
    x='file_name',
    y='t',
    hue='class',
    data=df_concat,
    aspect=16/9,
    facet_kws={'legend_out': False},
)

legend = g.axes.flat[0].get_legend()
legend.set_title('Codec')
for t, l in zip(legend.texts, ['Plain Quadtree', 'JPEG', 'Skip OOB blocks']):
    t.set_text(l)

# ticks = [2**x for x in range(3, 16)]
g.set(xlabel='File name', ylabel='Transcoding time (ms)',
      yscale='log') # , yticks=ticks, yticklabels=ticks)

plt.xticks(rotation=45)

plt.show()
